# %% [markdown]
# ## Boxwood - Displaying the Syntactic Structure of a Sentence

# %% [markdown]
# > *Important: this notebook does not display properly in GitHub, so please read it in nbviewer instead, using [this link](https://nbviewer.jupyter.org/github/biblicalhumanities/greek-new-testament/blob/master/labnotes/Boxwood%20-%20Syntax%20Structure.ipynb).

# %% [markdown]
# The `greeksyntax` package for Jupyter now supports [Boxwood](http://jonathanrobie.biblicalhumanities.org/blog/2017/05/12/lowfat-treebanks-visualizing/) diagrams to display the syntactic structure of a sentence.  Let's open a database and take a look at Matthew 1:20, take a look at it using Boxwood, and compare that to an interlinear display.

# %%
from greeksyntax.lowfat import *
q = lowfat("nestle1904lowfat")
# Out:
# Database 'nestle1904lowfat' was opened in 40.15 ms.

# %%
q.find(milestone("Matt.1.20"))
# Out:
# <p>
#   <b>Matt.1.20!1</b> <span title="pron :  οὗτος plural neuter accusative  -  These things">ταῦτα</span>
#   <span title="conj :  δέ  -  now">δὲ</span>
#   <span title="pron :  αὐτός singular masculine genitive  -  of him">αὐτοῦ</span>
#   <span title="verb :  ἐνθυμέομαι singular masculine genitive aorist passive participle  -  having pondered">ἐνθυμηθέντος</span>
#   <span title="verb :  ὁράω singular aorist middle imperative  -  behold">ἰδοὺ</span>
#   <span title="noun :  ἄγγελος singular masculine nominative  -  an angel">ἄγγελος</span>
#   <span title="noun :  κύριος singular masculine genitive  -  of [the] Lord">Κυρίου</span>
#   <span title="prep :  κατά  -  in">κατ’</span>
#   <span title="noun :  ὄναρ singular neuter accusative  -  a dream">ὄναρ</span>
#   <span title="verb :  φαίνω singular aorist passive indicative  -  appeared">ἐφάνη</span>
#   <span title="pron :  αὐτός singular masculine dative  -  to him">αὐτῷ</span>
# ...

# %% [markdown]
# You can wave your mouse above any word in the output shown above to see morphological information and an English gloss. You can also generate an interlinear - we will do that later.  But before we do that, be aware that interlinears have some drawbacks. As [Barry Hofstetter likes to put it](http://www.ibiblio.org/bgreek/forum/viewtopic.php?f=28&t=2162&p=12700#p12700):
#
# > There is not too much concerning which I am dogmatic. A few theological issues and the fact that interlinears are the spawn of the devil. They are the linguistic equivalent of brain eating zombies. They are the dark side, the power of which you don't want to experience...

# %% [markdown]
# The problem with interlinears is that they do not represent the syntactic structure of a Greek sentence at all.  Instead, the associate each word of the text with an English gloss and rely on your ability to connect English words to create meaning.  But the meaning of a Greek sentence cannot be accurately conveyed using English glosses.  Syntax diagrams do a much better job of that.
#
# There are [many kinds of syntax diagrams](http://jonathanrobie.biblicalhumanities.org/blog/2017/12/20/treebanks-for-ancient-greek/), the `greeksyntax` package for Jupyter supports Boxwood, a format designed to be simple and to avoid distracting readers with lots of overhead.  You can use the `q.boxwood()` method to display a sentence in this format:

# %%
q.boxwood(milestone("Matt.1.20"))
# Out:
# <style type="text/css">/* treedown.css */
#
# wg[class=header] {
#     display: block;
#     position: fixed;
#     width=6em;
#     top: 5px;
#     left: 15px;
#     background-color: white;
#     opacity: 1;
#     overflow: scroll;
# }
#
# milestone {
#     color: blue;
#     font-size: large;
#     display: inline;
#     padding-right: 6px;
# }
#
# p {
#     font-size: large;
#     display: inline;
#     margin-top: 1em;
#     margin-bottom: 1em;
# }
#
# div[class=book]  {
#   margin-top: 1in;
#   margin-left: 1in;
#   margin-bottom: 1in;
#   line-height: 1.2;
#   background-color: white;
#   opacity: 1;
# }
#
# book, passage,root {
#   line-height: 1.5;
#   margin-left: 5em;
#   margin-right: 10em;
#   /* background: linen; */
# }
#
#
#
# /* WGs */
#
# wg[class=sentence] {
# }
#
# wg[class=sentence] wg[class=cl]::before {
#   content: "";
# }
#
# wg[class=cl] {
#   /*
#     The nub of the spacing problem:
#
#     You really want spacing down to the last role before a word.
# ...

# %% [markdown]
# This display uses hierarchy and grouping to show the structure of the sentence.  Compare that to an interlinear for the same sentence:

# %%
q.interlinear(milestone("Matt.1.20"))
# Out:
# <table>
#   <tr>
#     <td style="text-align:left;">ταῦτα</td>
#     <td style="text-align:left;">These things</td>
#     <td style="text-align:left;">pron :  οὗτος plural neuter accusative</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">δὲ</td>
#     <td style="text-align:left;">now</td>
#     <td style="text-align:left;">conj :  δέ</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">αὐτοῦ</td>
#     <td style="text-align:left;">of him</td>
#     <td style="text-align:left;">pron :  αὐτός singular masculine genitive</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">ἐνθυμηθέντος</td>
#     <td style="text-align:left;">having pondered</td>
#     <td style="text-align:left;">verb :  ἐνθυμέομαι singular masculine genitive aorist passive participle</td>
#   </tr>
#   <tr>
#     <td style="text-align:left;">ἰδοὺ</td>
#     <td style="text-align:left;">behold</td>
#     <td style="text-align:left;">verb :  ὁράω singular aorist middle imperative</td>
#   </tr>
# ...

# %% [markdown]
# This display gives no real clue about the overall organization of the Greek sentence.  It can be helpful for vocabulary and parsing, but not for understanding sentence structure.
